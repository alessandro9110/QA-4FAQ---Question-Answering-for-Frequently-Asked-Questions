# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import pandas as pd
import csv

# %%
#epoch;acc;loss;val_acc;val_loss
df = pd.read_csv("log.csv", sep = ";", encoding = 'utf8', quotechar = '"',error_bad_lines=False)
df.head()
# Out:
#    epoch       acc      loss  mean_squared  val_acc  val_loss  \
# 0      0  0.487671  1.007568      0.312940      0.0  0.739127
# 1      1  0.539726  0.695893      0.250671      0.0  0.758413
# 2      2  0.560274  0.692210      0.246469      0.0  0.769690
# 3      3  0.556164  0.673155      0.240563      0.0  0.826002
# 4      4  0.561644  0.646521      0.228691      0.0  0.980811
#
#    val_mean_squared
# 0          0.272944
# 1          0.282479
# 2          0.288059
# 3          0.315527
# 4          0.380907

# %%
# summarize history for accuracy
plt.plot(df['acc'])
plt.plot(df['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('plot_acc',bbox_inches='tight')
plt.show()

  
# summarize history for loss
plt.plot(df['loss'])
plt.plot(df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('plot_loss',bbox_inches='tight')
plt.show()

# summarize history for loss
plt.plot(df['mean_squared'])
plt.plot(df['val_mean_squared'])
plt.title('model mean_squared')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('plot_squared',bbox_inches='tight')
plt.show()
